# %% [markdown]
# ### BUILD, RUN AND PLOT A NEURAL NETWORK

# %%
# %cd '/Users/juliencatanese/Dropbox/Datascientest/Projet_datascientest/Data_Kaggle/'
# %pwd

import os
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical 

from time import time
from joblib import dump, load

import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline

from sklearn import metrics
from sklearn.metrics import classification_report

import itertools
import tensorflow as tf

# import tensorflow as tf

# Lecture des donnees PTB.csv
ptb_abnormal = pd.read_csv('./ptbdb_abnormal.csv', header=None)
ptb_normal = pd.read_csv('./ptbdb_normal.csv', header=None)

# Concatenation des deux DataFrames
ptb = pd.concat([ptb_normal, ptb_abnormal], ignore_index=True, sort=False)
ptb.rename(columns={187 :'class'}, inplace=True)

# Lecture des donnees MIT.csv
mit_train = pd.read_csv('./mitbih_train.csv', header=None)
mit_test = pd.read_csv('./mitbih_test.csv', header=None)

# Concatenation des deux DataFrames
mit = pd.concat([mit_train, mit_test], ignore_index=True, sort=False)
mit.rename(columns={187 :'class'}, inplace=True)

# Groupement des classes non-normal (1,2,3,4) en une seule classe Anormal (label=1)
mit['class'].replace({2:1,3:1,4:1}, inplace=True)

# Concatenation des jeux de donnees PTB et MIT  
data = pd.concat([ptb, mit], ignore_index=True, sort=False)

y = data['class'].copy()
X = data.drop('class', axis=1).copy()

X_train90, X_valid, y_train90, y_valid = train_test_split(X, 
                                                          y, 
                                                          train_size=0.9, 
                                                          random_state=1,
                                                          shuffle=True)
X_train, X_test, y_train, y_test = train_test_split(X_train90, 
                                                    y_train90, 
                                                    train_size=0.8, 
                                                    random_state=1,
                                                    shuffle=True)

print('X_train.shape=',X_train.shape)
print('X_test.shape=',X_test.shape)
print('X_valid.shape=',X_valid.shape)

print('y_train.shape=',y_train.shape)
y_train_cat = to_categorical(y_train, dtype='int')
print('y_train_cat.shape=',y_train_cat.shape)


inputs = tf.keras.Input(
    shape=X_train.shape[1],
    batch_size=None,
    name='inputs',
    dtype=None,
    sparse=None,
    tensor=None,
    ragged=None,
    type_spec=None)

ACTIVATION = 'relu'
n_neurones_liste = [2, 10, 20, 50, 100, 200, 300, 500, 1000, 2000] 

for n_neurones in n_neurones_liste:

    dense_layer1 = tf.keras.layers.Dense(
        units = n_neurones,
        name='dense_layer1_' + ACTIVATION,
        activation=ACTIVATION,
        use_bias=True,
        kernel_initializer="normal",
        bias_initializer="zeros",
        kernel_regularizer=None,
        bias_regularizer=None,
        activity_regularizer=None,
        kernel_constraint=None,
        bias_constraint=None)

    layer2 = False
    if layer2:
        dense_layer2 = tf.keras.layers.Dense(
            units = 10,
            name='dense_layer2_' + ACTIVATION,
            activation= ACTIVATION,
            use_bias=True,
            kernel_initializer="normal",
            bias_initializer="zeros",
            kernel_regularizer=None,
            bias_regularizer=None,
            activity_regularizer=None,
            kernel_constraint=None,
            bias_constraint=None)

        layer3 = True
        if layer3:
            dense_layer3 = tf.keras.layers.Dense(
                units = 20,
                name='dense_layer3_' + ACTIVATION,
                activation= ACTIVATION,
                use_bias=True,
                kernel_initializer="normal",
                bias_initializer="zeros",
                kernel_regularizer=None,
                bias_regularizer=None,
                activity_regularizer=None,
                kernel_constraint=None,
                bias_constraint=None)

    dense_output = tf.keras.layers.Dense(
        units = 2,
        name='dense_output_softmax',
        activation='softmax',
        use_bias=True,
        kernel_initializer="normal",
        bias_initializer="zeros")

    x=dense_layer1(inputs)
    if layer2==True: 
        x=dense_layer2(x)
        if layer3==True: 
            x=dense_layer3(x)
    outputs = dense_output(x)

    model = Model(inputs = inputs, outputs =outputs)
    model.summary()


    model.compile(loss= 'BinaryCrossentropy', optimizer= 'adam', metrics=['accuracy'])

    epoch = 2*100 ; print('epoch=', epoch)
    batch_size = 10000; print('batch_size=',batch_size)

    t0 = time()
    train_history = model.fit(X_train, 
                              y_train_cat, 
                              batch_size=batch_size, 
                              epochs=epoch, 
                              validation_split =0.2, 
                              callbacks = tf.keras.callbacks.EarlyStopping(patience=20))
    t1 = time() - t0
    print("===== Réalisé en {} secondes ======".format(round(t1,3)))

    param_dense1 = {'units':dense_layer1.units,
        'name':dense_layer1.name,
        'activation':str(dense_layer1.activation).split(' ')[1],
        'use_bias':dense_layer1.use_bias,
        'kernel_initializer':dense_layer1.kernel_initializer,
        'bias_initializer':dense_layer1.bias_initializer}

    params = {'Layer1':param_dense1, 'batch_size':batch_size, 'train_time':round(t1,3)}

    param_L1_Name = str(params['Layer1']['activation']) + str(params['Layer1']['units'])+ 'u_' 

    paramName = 'L1_' + param_L1_Name; 

    if layer2:
        param_dense2 = {'units':dense_layer2.units,
            'name':dense_layer2.name,
            'activation':str(dense_layer2.activation).split(' ')[1],
            'use_bias':dense_layer2.use_bias,
            'kernel_initializer':dense_layer2.kernel_initializer,
            'bias_initializer':dense_layer2.bias_initializer}

        params = {'Layer1':param_dense1, 'Layer2':param_dense2, 'batch_size':batch_size, 'train_time':round(t1,3)}

        param_L2_Name = str(params['Layer2']['activation']) + str(params['Layer2']['units'])+ 'u_' 

        paramName = 'L2' + param_L2_Name +  'L1' + param_L1_Name

        if layer3:
            param_dense3 = {'units':dense_layer3.units,
            'name':dense_layer3.name,
            'activation':str(dense_layer3.activation).split(' ')[1],
            'use_bias':dense_layer3.use_bias,
            'kernel_initializer':dense_layer3.kernel_initializer,
            'bias_initializer':dense_layer3.bias_initializer}

            params = {'Layer1':param_dense1, 'Layer2':param_dense2, 'Layer3':param_dense3,
                      'batch_size':batch_size, 'train_time':round(t1,3)}

            param_L3_Name = str(params['Layer3']['activation']) + str(params['Layer3']['units'])+ 'u_'         

            paramName = 'L3'  +  param_L3_Name    + 'L2' + param_L2_Name +  'L1' + param_L1_Name

    SaveFileName = 'ANN_' + paramName + '.joblib'

    dump([model, params, train_history],SaveFileName)
    print('batch_size=',batch_size)
    print('Model saved as ', SaveFileName)

    print(model.summary())
    y_pred_cat = model.predict(X_test)
    y_pred = y_pred_cat.argmax(axis=1)
    print(classification_report(y_test, y_pred))


    train_set =train_history.history['accuracy']
    val_set =train_history.history['val_accuracy']

    plt.figure(n_neurones)
    plt.plot(train_set,label = 'train set');
    plt.plot(val_set, label= 'validation set');
    plt.ylabel('accuracy')
    plt.xlabel('epochs    \n(with batch_size ='+  str(params['batch_size'])  +')')
    plt.legend();
    plt.ylim([0.85,1])
    L1U= params['Layer1']['units']
    L1A= params['Layer1']['activation']
    TT = params['train_time']
    plt.title(str(L1U)+'units '+L1A +' train time='+str(int(TT))+'s')
# Out:
# /Users/juliencatanese/Dropbox/Datascientest/Projet_datascientest/Data_Kaggle
# 2023-05-11 15:59:52.353879: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# X_train.shape= (89278, 187)
# X_test.shape= (22320, 187)
# X_valid.shape= (12400, 187)
# y_train.shape= (89278,)
# y_train_cat.shape= (89278, 2)
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 187)]             0
#
#  dense_layer1_relu (Dense)   (None, 2)                 376
#
#  dense_output_softmax (Dense  (None, 2)                6
#  )
#
# =================================================================
# Total params: 382
# Trainable params: 382
# Non-trainable params: 0
# _________________________________________________________________
# epoch= 200
# batch_size= 10000
# Epoch 1/200
# 8/8 [==============================] - 1s 47ms/step - loss: 0.6927 - accuracy: 0.6182 - val_loss: 0.6907 - val_accuracy: 0.7608
# Epoch 2/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6894 - accuracy: 0.7643 - val_loss: 0.6873 - val_accuracy: 0.7609
# Epoch 3/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6856 - accuracy: 0.7643 - val_loss: 0.6828 - val_accuracy: 0.7609
# Epoch 4/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6807 - accuracy: 0.7643 - val_loss: 0.6772 - val_accuracy: 0.7609
# Epoch 5/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6745 - accuracy: 0.7643 - val_loss: 0.6704 - val_accuracy: 0.7609
# Epoch 6/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6673 - accuracy: 0.7643 - val_loss: 0.6627 - val_accuracy: 0.7609
# Epoch 7/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6593 - accuracy: 0.7643 - val_loss: 0.6544 - val_accuracy: 0.7609
# Epoch 8/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6509 - accuracy: 0.7643 - val_loss: 0.6460 - val_accuracy: 0.7609
# Epoch 9/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6425 - accuracy: 0.7643 - val_loss: 0.6381 - val_accuracy: 0.7609
# Epoch 10/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6349 - accuracy: 0.7643 - val_loss: 0.6311 - val_accuracy: 0.7609
# Epoch 11/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6282 - accuracy: 0.7643 - val_loss: 0.6252 - val_accuracy: 0.7609
# Epoch 12/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6227 - accuracy: 0.7643 - val_loss: 0.6205 - val_accuracy: 0.7609
# Epoch 13/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6184 - accuracy: 0.7643 - val_loss: 0.6168 - val_accuracy: 0.7609
# Epoch 14/200
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6149 - accuracy: 0.7643 - val_loss: 0.6137 - val_accuracy: 0.7609
# Epoch 15/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6120 - accuracy: 0.7643 - val_loss: 0.6112 - val_accuracy: 0.7609
# Epoch 16/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6096 - accuracy: 0.7643 - val_loss: 0.6090 - val_accuracy: 0.7609
# Epoch 17/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.6075 - accuracy: 0.7643 - val_loss: 0.6070 - val_accuracy: 0.7609
# Epoch 18/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.6055 - accuracy: 0.7643 - val_loss: 0.6050 - val_accuracy: 0.7609
# Epoch 19/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.
200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4088 - accuracy: 0.8419 - val_loss: 0.4100 - val_accuracy: 0.8423
# Epoch 199/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4086 - accuracy: 0.8416 - val_loss: 0.4099 - val_accuracy: 0.8423
# Epoch 200/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4084 - accuracy: 0.8419 - val_loss: 0.4097 - val_accuracy: 0.8425
# ===== Réalisé en 27.47 secondes ======
# batch_size= 10000
# Model saved as  ANN_L1_relu2u_.joblib
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 187)]             0
#
#  dense_layer1_relu (Dense)   (None, 2)                 376
#
#  dense_output_softmax (Dense  (None, 2)                6
#  )
#
# =================================================================
# Total params: 382
# Trainable params: 382
# Non-trainable params: 0
# _________________________________________________________________
# None
# 698/698 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.97      0.90     16935
#          1.0       0.83      0.43      0.57      5385
#
#     accuracy                           0.84     22320
#    macro avg       0.83      0.70      0.73     22320
# weighted avg       0.84      0.84      0.82     22320
#
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 187)]             0
#
#  dense_layer1_relu (Dense)   (None, 10)                1880
#
#  dense_output_softmax (Dense  (None, 2)                22
#  )
#
# =================================================================
# Total params: 1,902
# Trainable params: 1,902
# Non-trainable params: 0
# _________________________________________________________________
# epoch= 200
# batch_size= 10000
# Epoch 1/200
# 8/8 [==============================] - 1s 57ms/step - loss: 0.6901 - accuracy: 0.7207 - val_loss: 0.6855 - val_accuracy: 0.7609
# Epoch 2/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6817 - accuracy: 0.7643 - val_loss: 0.6747 - val_accuracy: 0.7609
# Epoch 3/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.6689 - accuracy: 0.7643 - val_loss: 0.6595 - val_accuracy: 0.7609
# Epoch 4/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6529 - accuracy: 0.7643 - val_loss: 0.6431 - val_accuracy: 0.7609
# Epoch 5/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.6371 - accuracy: 0.7643 - val_loss: 0.6293 - val_accuracy: 0.7609
# Epoch 6/200
# 8/8 [==============================] - 0s 22ms/step - loss: 0.6249 - accuracy: 0.7643 - val_loss: 0.6208 - val_accuracy: 0.7609
# Epoch 7/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6182 - accuracy: 0.7643 - val_loss: 0.6165 - val_accuracy: 0.7609
# Epoch 8/200
# 8/8 [==============================] - 0s 48ms/step - loss: 0.6146 - accuracy: 0.7643 - val_loss: 0.6134 - val_accuracy: 0.7609
# Epoch 9/200
# 8/8 [==============================] - 0s 31ms/step - loss: 0.6114 - accuracy: 0.7643 - val_loss: 0.6099 - val_accuracy: 0.7609
# Epoch 10/200
# 8/8 [==============================] - 0s 24ms/step - loss: 0.6076 - accuracy: 0.7643 - val_loss: 0.6059 - val_accuracy: 0.7609
# Epoch 11/200
# 8/8 [==============================] - 0s 28ms/step - loss: 0.6036 - accuracy: 0.7643 - val_loss: 0.6016 - val_accuracy: 0.7609
# Epoch 12/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5992 - accuracy: 0.7643 - val_loss: 0.5968 - val_accuracy: 0.7609
# Epoch 13/200
# 8/8 [==============================] - 0s 21ms/step - loss: 0.5941 - accuracy: 0.7643 - val_loss: 0.5914 - val_accuracy: 0.7609
# Epoch 14/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5885 - accuracy: 0.7643 - val_loss: 0.5854 - val_accuracy: 0.7609
# Epoch 15/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5823 - accuracy: 0.7643 - val_loss: 0.5788 - val_accuracy: 0.7609
# Epoch 16/200
# 8/8 [==============================] - 0s 16ms/step - loss: 0.5755 - accuracy: 0.7643 - val_loss: 0.5716 - val_accuracy: 0.7609
# Epoch 17/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5682 - accuracy: 0.7643 - val_loss: 0.5640 - val_accuracy: 0.7609
# Epoch 18/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5606 - accuracy: 0.7643 - val_loss: 0.5562 - val_accuracy: 0.7609
# Epoch 19/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.
200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4041 - accuracy: 0.8442 - val_loss: 0.4101 - val_accuracy: 0.8424
# Epoch 109/200
# 8/8 [==============================] - 0s 23ms/step - loss: 0.4034 - accuracy: 0.8439 - val_loss: 0.4092 - val_accuracy: 0.8429
# Epoch 110/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4026 - accuracy: 0.8442 - val_loss: 0.4085 - val_accuracy: 0.8435
# Epoch 111/200
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4018 - accuracy: 0.8451 - val_loss: 0.4078 - val_accuracy: 0.8436
# Epoch 112/200
# 8/8 [==============================] - 0s 20ms/step - loss: 0.4011 - accuracy: 0.8448 - val_loss: 0.4071 - val_accuracy: 0.8434
# Epoch 113/200
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4004 - accuracy: 0.8445 - val_loss: 0.4064 - val_accuracy: 0.8443
# Epoch 114/200
# ...
# Epoch 99/200
# 8/8 [==============================] - 1s 168ms/step - loss: 0.1306 - accuracy: 0.9542 - val_loss: 0.1491 - val_accuracy: 0.9458
# Epoch 100/200
# 8/8 [==============================] - 1s 192ms/step - loss: 0.1282 - accuracy: 0.9554 - val_loss: 0.1487 - val_accuracy: 0.9463
# Epoch 101/200
# 8/8 [==============================] - 1s 173ms/step - loss: 0.1281 - accuracy: 0.9552 - val_loss: 0.1519 - val_accuracy: 0.9406
# Epoch 102/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.1271 - accuracy: 0.9561 - val_loss: 0.1609 - val_accuracy: 0.9360
# Epoch 103/200
# 8/8 [==============================] - 1s 151ms/step - loss: 0.1302 - accuracy: 0.9542 - val_loss: 0.1476 - val_accuracy: 0.9442
# Epoch 104/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1255 - accuracy: 0.9560 - val_loss: 0.1467 - val_accuracy: 0.9444
# Epoch 105/200
# 8/8 [==============================] - 1s 151ms/step - loss: 0.1241 - accuracy: 0.9570 - val_loss: 0.1457 - val_accuracy: 0.9459
# Epoch 106/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1226 - accuracy: 0.9576 - val_loss: 0.1450 - val_accuracy: 0.9470
# Epoch 107/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1225 - accuracy: 0.9579 - val_loss: 0.1447 - val_accuracy: 0.9465
# Epoch 108/200
# 8/8 [==============================] - 1s 149ms/step - loss: 0.1217 - accuracy: 0.9574 - val_loss: 0.1439 - val_accuracy: 0.9469
# Epoch 109/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1213 - accuracy: 0.9581 - val_loss: 0.1464 - val_accuracy: 0.9440
# Epoch 110/200
# 8/8 [==============================] - 1s 149ms/step - loss: 0.1207 - accuracy: 0.9578 - val_loss: 0.1441 - val_accuracy: 0.9450
# Epoch 111/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1190 - accuracy: 0.9588 - val_loss: 0.1423 - val_accuracy: 0.9484
# Epoch 112/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.1186 - accuracy: 0.9587 - val_loss: 0.1412 - val_accuracy: 0.9486
# Epoch 113/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.1175 - accuracy: 0.9598 - val_loss: 0.1403 - val_accuracy: 0.9480
# Epoch 114/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.1164 - accuracy: 0.9602 - val_loss: 0.1408 - val_accuracy: 0.9494
# Epoch 115/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.1181 - accuracy: 0.9592 - val_loss: 0.1410 - val_accuracy: 0.9494
# Epoch 116/200
# 8/8 [==============================] - 1s 176ms/step - loss: 0.1162 - accuracy: 0.9601 - val_loss: 0.1387 - val_accuracy: 0.9493
# Epoch 117/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.1144 - accuracy: 0.9617 - val_loss: 0.1394 - val_accuracy: 0.9483
# Epoch 118/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1136 - accuracy: 0.9615 - val_loss: 0.1377 - val_accuracy: 0.9500
# Epoch 119/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1124 - accuracy: 0.9618 - val_loss: 0.1389 - val_accuracy: 0.9484
# Epoch 120/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1122 - accuracy: 0.9617 - val_loss: 0.1378 - val_accuracy: 0.9492
# Epoch 121/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1113 - accuracy: 0.9619 - val_loss: 0.1361 - val_accuracy: 0.9500
# Epoch 122/200
# 8/8 [==============================] - 1s 143ms/step - loss: 0.1108 - accuracy: 0.9625 - val_loss: 0.1422 - val_accuracy: 0.9455
# Epoch 123/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1122 - accuracy: 0.9617 - val_loss: 0.1406 - val_accuracy: 0.9461
# Epoch 124/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1114 - accuracy: 0.9618 - val_loss: 0.1393 - val_accuracy: 0.9474
# Epoch 125/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.1101 - accuracy: 0.9622 - val_loss: 0.1357 - val_accuracy: 0.9503
# Epoch 126/200
# 8/8 [==============================] - 1s 163ms/step - loss: 0.1088 - accuracy: 0.9630 - val_loss: 0.1435 - val_accuracy: 0.9447
# Epoch 127/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1090 - accuracy: 0.9624 - val_loss: 0.1347 - val_accuracy: 0.9508
# Epoch 128/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1066 - accuracy: 0.9643 - val_loss: 0.1343 - val_accuracy: 0.9509
# Epoch 129/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.1059 - accuracy: 0.9643 - val_loss: 0.1362 - val_accuracy: 0.9490
# Epoch 130/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1062 - accuracy: 0.9646 - val_loss: 0.1409 - val_accuracy: 0.9457
# Epoch 131/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1069 - accuracy: 0.9635 - val_loss: 0.1314 - val_accuracy: 0.9530
# Epoch 132/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1044 - accuracy: 0.9643 - val_loss: 0.1316 - val_accuracy: 0.9528
# Epoch 133/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.1039 - accuracy: 0.9645 - val_loss: 0.1305 - val_accuracy: 0.9528
# Epoch 134/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.1032 - accuracy: 0.9654 - val_loss: 0.1310 - val_accuracy: 0.9526
# Epoch 135/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.1026 - accuracy: 0.9659 - val_loss: 0.1302 - val_accuracy: 0.9537
# Epoch 136/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.1030 - accuracy: 0.9652 - val_loss: 0.1329 - val_accuracy: 0.9507
# Epoch 137/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.1023 - accuracy: 0.9655 - val_loss: 0.1336 - val_accuracy: 0.9496
# Epoch 138/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.1019 - accuracy: 0.9653 - val_loss: 0.1305 - val_accuracy: 0.9533
# Epoch 139/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.1012 - accuracy: 0.9663 - val_loss: 0.1298 - val_accuracy: 0.9530
# Epoch 140/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0992 - accuracy: 0.9669 - val_loss: 0.1329 - val_accuracy: 0.9536
# Epoch 141/200
# 8/8 [==============================] - 1s 164ms/step - loss: 0.1022 - accuracy: 0.9656 - val_loss: 0.1278 - val_accuracy: 0.9541
# Epoch 142/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0986 - accuracy: 0.9671 - val_loss: 0.1287 - val_accuracy: 0.9540
# Epoch 143/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0978 - accuracy: 0.9672 - val_loss: 0.1281 - val_accuracy: 0.9544
# Epoch 144/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0986 - accuracy: 0.9676 - val_loss: 0.1270 - val_accuracy: 0.9545
# Epoch 145/200
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0963 - accuracy: 0.9678 - val_loss: 0.1264 - val_accuracy: 0.9544
# Epoch 146/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0975 - accuracy: 0.9672 - val_loss: 0.1263 - val_accuracy: 0.9550
# Epoch 147/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0971 - accuracy: 0.9679 - val_loss: 0.1263 - val_accuracy: 0.9546
# Epoch 148/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0956 - accuracy: 0.9683 - val_loss: 0.1255 - val_accuracy: 0.9546
# Epoch 149/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0955 - accuracy: 0.9685 - val_loss: 0.1257 - val_accuracy: 0.9553
# Epoch 150/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0957 - accuracy: 0.9689 - val_loss: 0.1249 - val_accuracy: 0.9547
# Epoch 151/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0940 - accuracy: 0.9696 - val_loss: 0.1244 - val_accuracy: 0.9554
# Epoch 152/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0932 - accuracy: 0.9694 - val_loss: 0.1242 - val_accuracy: 0.9551
# Epoch 153/200
# 8/8 [==============================] - 1s 145ms/step - loss: 0.0929 - accuracy: 0.9692 - val_loss: 0.1257 - val_accuracy: 0.9546
# Epoch 154/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0937 - accuracy: 0.9697 - val_loss: 0.1240 - val_accuracy: 0.9553
# Epoch 155/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0923 - accuracy: 0.9701 - val_loss: 0.1239 - val_accuracy: 0.9553
# Epoch 156/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0910 - accuracy: 0.9704 - val_loss: 0.1239 - val_accuracy: 0.9550
# Epoch 157/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0910 - accuracy: 0.9702 - val_loss: 0.1286 - val_accuracy: 0.9531
# Epoch 158/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0912 - accuracy: 0.9698 - val_loss: 0.1237 - val_accuracy: 0.9554
# Epoch 159/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0907 - accuracy: 0.9711 - val_loss: 0.1259 - val_accuracy: 0.9542
# Epoch 160/200
# 8/8 [==============================] - 1s 166ms/step - loss: 0.0902 - accuracy: 0.9704 - val_loss: 0.1226 - val_accuracy: 0.9554
# Epoch 161/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0894 - accuracy: 0.9712 - val_loss: 0.1214 - val_accuracy: 0.9563
# Epoch 162/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0891 - accuracy: 0.9713 - val_loss: 0.1221 - val_accuracy: 0.9569
# Epoch 163/200
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0878 - accuracy: 0.9719 - val_loss: 0.1212 - val_accuracy: 0.9574
# Epoch 164/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0881 - accuracy: 0.9715 - val_loss: 0.1227 - val_accuracy: 0.9571
# Epoch 165/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0880 - accuracy: 0.9712 - val_loss: 0.1209 - val_accuracy: 0.9563
# Epoch 166/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0865 - accuracy: 0.9721 - val_loss: 0.1233 - val_accuracy: 0.9559
# Epoch 167/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0860 - accuracy: 0.9725 - val_loss: 0.1196 - val_accuracy: 0.9571
# Epoch 168/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0860 - accuracy: 0.9727 - val_loss: 0.1202 - val_accuracy: 0.9568
# Epoch 169/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0850 - accuracy: 0.9731 - val_loss: 0.1195 - val_accuracy: 0.9566
# Epoch 170/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0854 - accuracy: 0.9724 - val_loss: 0.1215 - val_accuracy: 0.9555
# Epoch 171/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0855 - accuracy: 0.9723 - val_loss: 0.1196 - val_accuracy: 0.9572
# Epoch 172/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0843 - accuracy: 0.9731 - val_loss: 0.1184 - val_accuracy: 0.9572
# Epoch 173/200
# 8/8 [==============================] - 1s 153ms/step - loss: 0.0837 - accuracy: 0.9741 - val_loss: 0.1190 - val_accuracy: 0.9567
# Epoch 174/200
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0831 - accuracy: 0.9734 - val_loss: 0.1182 - val_accuracy: 0.9574
# Epoch 175/200
# 8/8 [==============================] - 1s 157ms/step - loss: 0.0829 - accuracy: 0.9737 - val_loss: 0.1200 - val_accuracy: 0.9560
# Epoch 176/200
# 8/8 [==============================] - 1s 166ms/step - loss: 0.0828 - accuracy: 0.9739 - val_loss: 0.1242 - val_accuracy: 0.9545
# Epoch 177/200
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0840 - accuracy: 0.9736 - val_loss: 0.1234 - val_accuracy: 0.9550
# Epoch 178/200
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0825 - accuracy: 0.9736 - val_loss: 0.1185 - val_accuracy: 0.9569
# Epoch 179/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0811 - accuracy: 0.9746 - val_loss: 0.1189 - val_accuracy: 0.9568
# Epoch 180/200
# 8/8 [==============================] - 1s 144ms/step - loss: 0.0803 - accuracy: 0.9748 - val_loss: 0.1201 - val_accuracy: 0.9570
# Epoch 181/200
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0808 - accuracy: 0.9746 - val_loss: 0.1165 - val_accuracy: 0.9579
# Epoch 182/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0800 - accuracy: 0.9752 - val_loss: 0.1171 - val_accuracy: 0.9583
# Epoch 183/200
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0798 - accuracy: 0.9751 - val_loss: 0.1165 - val_accuracy: 0.9579
# Epoch 184/200
# 8/8 [==============================] - 1s 165ms/step - loss: 0.0786 - accuracy: 0.9757 - val_loss: 0.1175 - val_accuracy: 0.9583
# Epoch 185/200
# 8/8 [==============================] - 1s 159ms/step - loss: 0.0784 - accuracy: 0.9753 - val_loss: 0.1160 - val_accuracy: 0.9589
# Epoch 186/200
# 8/8 [==============================] - 1s 156ms/step - loss: 0.0788 - accuracy: 0.9752 - val_loss: 0.1192 - val_accuracy: 0.9564
# Epoch 187/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0780 - accuracy: 0.9755 - val_loss: 0.1165 - val_accuracy: 0.9579
# Epoch 188/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0773 - accuracy: 0.9757 - val_loss: 0.1176 - val_accuracy: 0.9568
# Epoch 189/200
# 8/8 [==============================] - 1s 158ms/step - loss: 0.0773 - accuracy: 0.9757 - val_loss: 0.1159 - val_accuracy: 0.9586
# Epoch 190/200
# 8/8 [==============================] - 1s 148ms/step - loss: 0.0768 - accuracy: 0.9762 - val_loss: 0.1202 - val_accuracy: 0.9565
# Epoch 191/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0782 - accuracy: 0.9748 - val_loss: 0.1166 - val_accuracy: 0.9569
# Epoch 192/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0768 - accuracy: 0.9756 - val_loss: 0.1153 - val_accuracy: 0.9589
# Epoch 193/200
# 8/8 [==============================] - 1s 151ms/step - loss: 0.0769 - accuracy: 0.9756 - val_loss: 0.1166 - val_accuracy: 0.9577
# Epoch 194/200
# 8/8 [==============================] - 1s 152ms/step - loss: 0.0766 - accuracy: 0.9756 - val_loss: 0.1148 - val_accuracy: 0.9591
# Epoch 195/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0751 - accuracy: 0.9770 - val_loss: 0.1230 - val_accuracy: 0.9555
# Epoch 196/200
# 8/8 [==============================] - 1s 149ms/step - loss: 0.0780 - accuracy: 0.9749 - val_loss: 0.1186 - val_accuracy: 0.9569
# Epoch 197/200
# 8/8 [==============================] - 1s 146ms/step - loss: 0.0755 - accuracy: 0.9762 - val_loss: 0.1204 - val_accuracy: 0.9563
# Epoch 198/200
# 8/8 [==============================] - 1s 147ms/step - loss: 0.0757 - accuracy: 0.9759 - val_loss: 0.1132 - val_accuracy: 0.9587
# Epoch 199/200
# 8/8 [==============================] - 1s 154ms/step - loss: 0.0741 - accuracy: 0.9776 - val_loss: 0.1152 - val_accuracy: 0.9591
# Epoch 200/200
# 8/8 [==============================] - 1s 150ms/step - loss: 0.0746 - accuracy: 0.9768 - val_loss: 0.1134 - val_accuracy: 0.9590
# ===== Réalisé en 242.789 secondes ======
# batch_size= 10000
# Model saved as  ANN_L1_relu2000u_.joblib
# Model: "model_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 187)]             0
#
#  dense_layer1_relu (Dense)   (None, 2000)              376000
#
#  dense_output_softmax (Dense  (None, 2)                4002
#  )
#
# =================================================================
# Total params: 380,002
# Trainable params: 380,002
# Non-trainable params: 0
# _________________________________________________________________
# None
# 698/698 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     16935
#          1.0       0.94      0.88      0.91      5385
#
#     accuracy                           0.96     22320
#    macro avg       0.95      0.93      0.94     22320
# weighted avg       0.96      0.96      0.96     22320

# %%
n_neurones_liste = [2, 10, 20, 50, 100, 200, 300, 500, 1000, 2000] 
All_model=[]
All_hist=[]
All_params=[]
for n_neurones in n_neurones_liste:
    LoadFileName = 'ANN_L1_relu' + str(n_neurones) + 'u_.joblib'
    model, params, train_history = load(LoadFileName)
    All_model.append(model)
    All_hist.append(train_history)   
    All_params.append(params)
    
plt.plot(np.log(n_neurones_liste), all_Acc_val, label = 'accuracy_validation')
plt.plot(np.log(n_neurones_liste), all_Acc, label = 'accuracy_train')
plt.xticks(np.log(n_neurones_liste), n_neurones_liste)
plt.legend()
plt.ylim([0.84, 1])
plt.ylabel('accuracy score')
plt.xlabel('nombre de neurones')
plt.title("Performances en fonction du nombre de neurones \n Model a une unique couche intermediaire")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/fr/j3w14lqd18702_9chfn3vk580000gn/T/ipykernel_1475/420516238.py in <module>
#      10     All_params.append(params)
#      11
# ---> 12 plt.plot(np.log(n_neurones_liste), all_Acc_val, label = 'accuracy_validation')
#      13 plt.plot(np.log(n_neurones_liste), all_Acc, label = 'accuracy_train')
#      14 plt.xticks(np.log(n_neurones_liste), n_neurones_liste)
#
# NameError: name 'all_Acc_val' is not defined

# %%
timetr=[]
for i in range(len(All_hist)):
    timetr.append(All_params[i]['train_time']/60)
plt.plot(np.log(n_neurones_liste), timetr)
plt.xticks(np.log(n_neurones_liste), n_neurones_liste)
plt.ylabel('time to compute (min)')
plt.xlabel('nombre de neurones')
plt.title("temps d'apprentissage pour une seule couche intermediaire")
